# %%
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('bmh')
import seaborn as sns

# %%
x = np.linspace(0,3, 50)
x
# Out:
# array([0.        , 0.06122449, 0.12244898, 0.18367347, 0.24489796,
#        0.30612245, 0.36734694, 0.42857143, 0.48979592, 0.55102041,
#        0.6122449 , 0.67346939, 0.73469388, 0.79591837, 0.85714286,
#        0.91836735, 0.97959184, 1.04081633, 1.10204082, 1.16326531,
#        1.2244898 , 1.28571429, 1.34693878, 1.40816327, 1.46938776,
#        1.53061224, 1.59183673, 1.65306122, 1.71428571, 1.7755102 ,
#        1.83673469, 1.89795918, 1.95918367, 2.02040816, 2.08163265,
#        2.14285714, 2.20408163, 2.26530612, 2.32653061, 2.3877551 ,
#        2.44897959, 2.51020408, 2.57142857, 2.63265306, 2.69387755,
#        2.75510204, 2.81632653, 2.87755102, 2.93877551, 3.        ])

# %%
y = np.exp(x)

# %%
plt.plot(x, y)

# %%
y
# Out:
# array([ 1.        ,  1.06313755,  1.13026145,  1.20162339,  1.27749095,
#         1.3581486 ,  1.44389878,  1.53506301,  1.63198313,  1.73502255,
#         1.84456762,  1.9610291 ,  2.08484368,  2.2164756 ,  2.35641844,
#         2.50519693,  2.66336893,  2.83152752,  3.01030324,  3.20036641,
#         3.40242971,  3.61725079,  3.84563514,  4.08843913,  4.34657316,
#         4.62100514,  4.91276409,  5.22294398,  5.55270788,  5.90329225,
#         6.27601167,  6.67226367,  7.09353406,  7.54140243,  8.01754811,
#         8.52375646,  9.06192557,  9.63407336, 10.24234515, 10.88902174,
#        11.57652791, 12.30744153, 13.08450324, 13.91062673, 14.78890964,
#        15.72264517, 16.71533448, 17.77069977, 18.89269823, 20.08553692])

# %%
np.mean(y)
# Out:
# 1.7231417144384698

# %%
np.random.rand() # FORM U[0,1]
# Out:
# 0.8633738158492796

# %%
z = np.max(y) / (np.max(y) + y)
z
# Out:
# array([0.73105858, 0.72422509, 0.71728511, 0.71024037, 0.70309274,
#        0.6958443 , 0.68849731, 0.6810542 , 0.67351757, 0.66589021,
#        0.65817511, 0.65037538, 0.64249436, 0.63453551, 0.62650248,
#        0.61839907, 0.61022923, 0.60199704, 0.59370676, 0.58536272,
#        0.57696943, 0.56853146, 0.56005353, 0.55154041, 0.54299699,
#        0.53442819, 0.52583903, 0.51723455, 0.50861984, 0.5       ])

# %%
y = y-1

# %%
z = y**3 / (0.3 + y**3)
z
# Out:
# array([0.00000000e+00, 1.43929659e-04, 1.21180669e-03, 4.29684633e-03,
#        1.06682539e-02, 2.17263131e-02, 3.89052953e-02, 6.35162846e-02,
#        9.65385966e-02, 1.38393914e-01, 1.88762772e-01, 2.46512389e-01,
#        3.09783330e-01, 3.76231222e-01, 4.43361846e-01, 5.08865589e-01,
#        5.70867541e-01, 6.28051827e-01, 6.79666231e-01, 7.25443594e-01,
#        7.65483919e-01, 8.00132457e-01, 8.29874769e-01, 8.55256931e-01,
#        8.76830808e-01, 8.95120192e-01, 9.10602486e-01, 9.23701007e-01,
#        9.34783995e-01, 9.44167496e-01])

# %%
plt.plot(z)
